# %%
import hdc
hdc.connect()
# Out:
# Database is already connected.

# %%
import os
print(f"Current Directory: {os.getcwd()}")
print(f"Files found: {os.listdir('.')}")
# Out:
# Current Directory: /home/jovyan/work/_ShareInProvince/Telemed_KET10
# Files found: ['.ipynb_checkpoints', 'Export', 'q_telemed_hosp.ipynb', 'Import_icd10_chk_op_CSV.ipynb', 'q_telemed_hosp_muk.ipynb', 'op_instype_all.ipynb', 'q_telemed_hosp-235.ipynb', 'icd10_chk_op.csv']

# %%
# %%sql
# DROP TABLE IF EXISTS icd10_chk_op ;
# CREATE TABLE icd10_chk_op (
#     d_CODE varchar NOT NULL,
#     DESC_R varchar DEFAULT NULL,
#     DISEASE_TH varchar DEFAULT NULL,
#     VALID varchar DEFAULT NULL,
#     ICD10_2010 varchar DEFAULT NULL,
#     PDX varchar DEFAULT NULL,
#     WHO varchar DEFAULT NULL,
#     icd10TM varchar DEFAULT NULL,
#     icd10TMD varchar DEFAULT NULL,
#     CHK_ICD varchar DEFAULT NULL,
#     SEX varchar DEFAULT NULL,
#     AGEDUSE varchar DEFAULT NULL,
#     AGEMIN varchar DEFAULT NULL,
#     AGEMAX varchar DEFAULT NULL,
#     AGEDMIN varchar DEFAULT NULL,
#     R506_CODE varchar DEFAULT NULL,
#     R506_NAME varchar DEFAULT NULL,
#     R506_GROUP varchar DEFAULT NULL,
#     GROUP21 varchar DEFAULT NULL,
#     GROUP21NAME varchar DEFAULT NULL,
#     GROUP298 varchar DEFAULT NULL,
#     GROUP298NAME varchar DEFAULT NULL,
#     GROUP19 varchar DEFAULT NULL,
#     GROUP19NAME varchar DEFAULT NULL,
#     CHRONIC varchar DEFAULT NULL,
#     OP_PP varchar DEFAULT NULL,
#     DX20_AUDIT varchar DEFAULT NULL,
#     DX20_DISEASE varchar DEFAULT NULL,
#     CODE3 varchar DEFAULT NULL,
#     PRIMARY KEY (d_CODE)
# ) ;
# INSERT INTO icd10_chk_op (d_CODE,DESC_R,DISEASE_TH,VALID,ICD10_2010,PDX,WHO,icd10TM,icd10TMD,CHK_ICD,SEX,AGEDUSE,AGEMIN,AGEMAX,AGEDMIN,R506_CODE,R506_NAME
#     ,R506_GROUP,GROUP21,GROUP21NAME,GROUP298,GROUP298NAME,GROUP19,GROUP19NAME,CHRONIC,OP_PP,DX20_AUDIT,DX20_DISEASE,CODE3)
# SELECT d_CODE,DESC_R,DISEASE_TH,VALID,ICD10_2010,PDX,WHO,icd10TM,icd10TMD,CHK_ICD,SEX,AGEDUSE,AGEMIN,AGEMAX,AGEDMIN,R506_CODE,R506_NAME
#     ,R506_GROUP,GROUP21,GROUP21NAME,GROUP298,GROUP298NAME,GROUP19,GROUP19NAME,CHRONIC,OP_PP,DX20_AUDIT,DX20_DISEASE,CODE3
# FROM 'icd10_chk_op.csv';
# Out:
# +-------+
# | Count |
# +-------+
# | 41716 |
# +-------+

# %%
hdc.close()
